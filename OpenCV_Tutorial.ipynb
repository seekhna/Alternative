# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv.imread("watch.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.title(" Watch image")
plt.axis("off")
plt.show()


print("The dimensions of the image are",img.shape)
print("The dimensions of the image are {dims}".format(dims=img.shape))
# Out:
# The dimensions of the image are (168, 300, 3)
# The dimensions of the image are (168, 300, 3)

# %%
cam = cv.VideoCapture(0)
cam.open(0)
while cam.isOpened():
    ret, frame = cam.read()
    if not ret:
       continue
    cv.imshow('Live feed', frame)
    key = cv.waitKey(1)
    if key == ord('q'):
       break
print("Done")
cv.destroyWindow('Live feed')
cv.destroyAllWindows()
cam.release()
# Out:
# Done

# %%
# import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
file = "index.mp4"
tdelay = 6
vid_reader = cv.VideoCapture(file)
while (vid_reader.isOpened()):
    ret, img = vid_reader.read()
    if not ret:
        break
    cv.imshow('Frame', img)
    key = cv.waitKey(tdelay) & 0xFF
    if key == ord('q'):
        break
cv.destroyAllWindows()
vid_reader.release()

# %%
## A colour thresholding examples
# Play around with the RGB mask values to see better effect

# import the necessary packages
import numpy as np
import cv2 
# load the image
image = cv2.imread('yellowmask.jpg',1)
# define the list of boundaries
boundaries = [([17, 15, 100], [50, 56, 200]),
              ([86, 31, 4], [220, 88, 50]),
            ([25, 146, 190], [62, 174, 250]),
([103, 86, 65], [145, 133, 128])]

# loop over the boundaries
for (lower, upper) in boundaries:
	# create NumPy arrays from the boundaries
	lower = np.array(lower, dtype = "uint8")
	upper = np.array(upper, dtype = "uint8")

	# find the colors within the specified boundaries and apply
	# the mask
	mask = cv2.inRange(image, lower, upper)
	output = cv2.bitwise_and(image, image, mask = mask)

	# show the images
	cv2.imshow("images", np.hstack([image, output]))
	cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('group.jpg')

kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('group.jpg')

blur = cv2.blur(img,(5,5))
cv2.imwrite('grouptest4.jpg', blur)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('group.jpg')

blur = cv2.GaussianBlur(img,(5,5),0)
cv2.imwrite('grouptest3.jpg', blur)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('group.jpg')

median = cv2.medianBlur(img,5)
cv2.imwrite('grouptest2.jpg', median)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('group.jpg')
blur = cv2.bilateralFilter(img,9,75,75)
cv2.imwrite('grouptest1.jpg', blur)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('group.jpg',cv2.IMREAD_GRAYSCALE)
rows,cols = img.shape
 
sobel_horizontal = cv2.Sobel(img,cv2.CV_64F,1,0,ksize = 5)
sobel_vertical = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)
 
cv2.imshow('Original',img)
cv2.imshow('Sobel Horizontal Filter',sobel_horizontal)
cv2.imshow('Sobel Vertical Filter',sobel_vertical)
 
cv2.waitKey(0)
# Out:
# -1

# %%
mg = cv2.imread('group.jpg',cv2.IMREAD_GRAYSCALE)
rows,cols = img.shape
 
denoised = cv2.GaussianBlur(img,(5,5),0)
filter = cv2.Laplacian(denoised,cv2.CV_64F)
 
cv2.imshow('Original',img)
cv2.imshow('Laplacian Filter',filter)
 
cv2.waitKey(0)
# Out:
# -1

# %%
import cv2
import numpy as np
 
img = cv2.imread('group.jpg',cv2.IMREAD_GRAYSCALE)
 
filter = cv2.Canny(img,100,200)
 
cv2.imshow('Original',img)
cv2.imshow('Laplacian Filter',filter)
 
cv2.waitKey(0)
# Out:
# 120

# %%
import numpy as np
import argparse
import cv2
 
cap = cv2.VideoCapture(0)
 
while(1):
    ret, frame = cap.read()
    gray_vid = cv2.cvtColor(frame, cv2.IMREAD_GRAYSCALE)
    cv2.imshow('Original',frame)
    edged_frame = cv2.Canny(frame,100,200)
    cv2.imshow('Edges',edged_frame)
    k= cv2.waitKey(5)& 0xFF
    if k == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
